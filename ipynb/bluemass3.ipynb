# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("white")
sns.set_context("talk")

import os, sys
import numpy as np

# %%
res = np.load("../data/test.npz")
ys = res['ys']
times = res['times']

# %%
plt.plot(times, ys[:,0], label='E')
plt.plot(times, ys[:,1], label='I')
plt.legend()

# %%
plt.plot(times, ys[:,2], label='EE')
plt.plot(times, ys[:,3], label='EI')
plt.plot(times, ys[:,4], label='IE')
plt.plot(times, ys[:,5],label='II')
plt.legend()

# %%
plt.plot(times, ys[:,6], label='EE')
plt.plot(times, ys[:,7], label='EI')
plt.plot(times, ys[:,8], label='IE')
plt.plot(times, ys[:,9],label='II')
plt.legend()
