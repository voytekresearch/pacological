# %%
# %matplotlib inline
# %run ../jr.py

# %%
rs[:,:]
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           1.00000000e+00,   1.00000000e+00,   1.00000000e+00],
#        [  9.66045284e+02,   8.59296636e+02,   9.15319799e+02, ...,
#          -8.75514579e+06,  -2.37077733e+06,   5.16505117e+05],
#        [  5.68864376e+07,   4.45727919e+08,   3.05910125e+07, ...,
#          -4.54642475e+12,  -7.95366141e+10,   2.68213336e+11],
#        ...,
#        [             nan,              nan,              nan, ...,
#                      nan,              nan,              nan],
#        [             nan,              nan,              nan, ...,
#                      nan,              nan,              nan],
#        [             nan,              nan,              nan, ...,
#                      nan,              nan,              nan]])
