# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
import numpy as np
from pacological.util import phi_sigma, phi

# %%
I = np.linspace(0, 1, 100)
fi = phi_sigma(I, .2, .10)
plt.plot(I, fi)
