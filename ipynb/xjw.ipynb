# %%
# %matplotlib inline
# %run ../xjw.py
# Out:
# Mean re1 : 33.4084509255
# Mean ri1: 17.2601729856
# Max STIM F (Hz) 7.0
# Mean re2 : 67.0600955004
# Mean ri2: 49.9575605964
# Max OSC F (Hz) 7.0

# %% [markdown]
# #
