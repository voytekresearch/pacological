# %%
# %matplotlib inline
# %run ../xjw.py
# Out:
# Mean re1 : 12.6134890509
# Mean ri1: 13.3344329181
# Max STIM F (Hz) 7.37448559671
# Mean re2 : 45.8063068513
# Mean ri2: 34.8872992931
# Max OSC F (Hz) 7.37448559671
# /home/ejp/anaconda/lib/python2.7/site-packages/scipy/signal/spectral.py:281: UserWarning: nperseg = 1024, is greater than x.shape[-1] = 972, using nperseg = x.shape[-1]
#   % (nperseg, axis, x.shape[axis], axis))

# %% [markdown]
# #
